# %% [markdown]
# # REFINITIV DISCOUNTED CASH FLOW ANALYSIS
#
# ### Instructions
#
# This notebook will provides all of the code needed to conduct and in-depth Discounted Cash Flow (DCF) analysis for a company and also - to provide a relative valuation overlay - a DCF analysis for all of the peers of the company - in this case Vodafone PLC (RIC: VOD.L). Before we do this we provide an introduction to our fundamental and estimate content offering to help you navigate these substantial content sets. Just run each cell sequentially using shift + enter.

# %% [markdown]
# ### Overview
#
# \- Introduction to Refinitiv Company Fundamentals (RCF) & Estimates Dataset
#
# \- Conduct Discounted Cashflow (DCF) type instrinsic valuation
#
# \- Scale to calculate DCF for peers to provide a relative value overlay
#
# \- Use unsupervised ML routines to generate classification groupings for our data

# %% [markdown]
# ###  Refinitiv Company Fundamental (RCF) data
#
# \- New Strategic Content Set (see RCFLAND for much more info)
#
# \- Both company specific (ASR) and standardised data to enhance comparison internationally, via different accounting standards and across industries
#
# \- RCF contains 60% more content than previous Refinitiv Fundamentals content set
#
# \- IS, CF, BS statements available via one field call - vastly improved workflow

# %%
import refinitiv.data as rd
from refinitiv.data.discovery import Peers
import numpy as np
import numpy_financial as npf
from numpy import where
from numpy import unique
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from sklearn.linear_model import LinearRegression
import ipywidgets as widgets
from ipywidgets import Box, Label, Layout
import matplotlib as plt
import warnings

# %matplotlib inline
plt.style.use("seaborn")
warnings.filterwarnings("ignore")
rd.open_session()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import refinitiv.data as rd
#       2 from refinitiv.data.discovery import Peers
#       3 import numpy as np
#
# ModuleNotFoundError: No module named 'refinitiv'

# %% [markdown]
# \- 5 Industry Templates - Industrial, Property, Bank, Insurance, Other FInancial
#
# \- Standardised or As Reported (ASR)
#
# \- One API call to get all fields for a particular statement - plenty of parameters so check DIB for more available parameters
#
# ### Income Statement

# %%
df = rd.get_data(['VOD.L'], ['TR.F.IncomeStatement.fieldname', 'TR.F.IncomeStatement.fielddescription', 'TR.F.IncomeStatement'],
                 parameters={'Period': 'FY0', 'reportingState': 'Rsdt', 'curn': 'Native', 'Scale': '6', 'SORTA': 'LISeq'})
df
# Out:
#     Instrument                               Name  \
# 0        VOD.L                  TR.F.RevGoodsSrvc
# 1        VOD.L  TR.F.SalesOfGoodsSrvcNetUnclassif
# 2        VOD.L          TR.F.RevBizRelActivOthTot
# 3        VOD.L                    TR.F.TotRevenue
# 4        VOD.L                   TR.F.CostOfOpRev
# ..         ...                                ...
# 143      VOD.L        TR.F.COGSInclOpMaintUtilTot
# 144      VOD.L                  TR.F.COGSExclDepr
# 145      VOD.L                      TR.F.IntrExpn
# 146      VOD.L                        TR.F.OpExpn
# 147      VOD.L                    TR.F.SGAExclRnD
#
#                                            Description  \
# 0    Revenue from Goods & Services [SNTS] represent...
# 1    Sales of Goods & Services - Net - Unclassified...
# 2    Revenue from Business-Related Activities - Oth...
# 3    Revenue from Business Activities - Total [STLR...
# 4    Cost of Operating Revenue [SCOR] represents th...
# ..                                                 ...
# 143  Cost of Revenue including Operation & Maintena...
# 144  Cost of Revenues excluding Depreciation [SCOGX...
# 145  Interest Expense [SINTEX] represents Net inter...
# 146  Operating Expenses [SOPEX] represents the tota...
# 147  Selling, General & Administrative Expenses exc...
#
#      STD Income Statement All
# 0                     38203.0
# 1                     38203.0
# 2                      7377.0
# 3                     45580.0
# 4                     30574.0
# ..                        ...
# 143                   30574.0
# 144                   30574.0
# 145                    2413.0
# 146                   39848.0
# 147                    9632.0
#
# [148 rows x 4 columns]

# %% [markdown]
# ### Cash Flow Statement

# %%
df1 = rd.get_data(['VOD.L'], ['TR.F.CashflowStatement.fieldname', 'TR.F.CashflowStatement.fielddescription', 'TR.F.CashflowStatement'],
                  parameters={'Period': 'FY0', 'reportingState': 'Rsdt', 'curn': 'Native', 'Scale': '6', 'SORTA': 'LISeq'})
df1
# Out:
#    Instrument                          Name  \
# 0       VOD.L   TR.F.ProfLossStartingLineCF
# 1       VOD.L  TR.F.NonCashItemsReconcAdjCF
# 2       VOD.L     TR.F.EqIncLossInNetEarnCF
# 3       VOD.L             TR.F.IncTaxExpnCF
# 4       VOD.L             TR.F.FinIncExpnCF
# ..        ...                           ...
# 62      VOD.L       TR.F.ComStockBuybackNet
# 63      VOD.L          TR.F.DeprDeplAmortCF
# 64      VOD.L         TR.F.FreeCashFlowToEq
# 65      VOD.L                     TR.F.FOCF
# 66      VOD.L              TR.F.LeveredFOCF
#
#                                           Description  STD Cash Flow All
# 0   Profit/(Loss) - Starting Line - Cash Flow [SPL...               2624
# 1   Non-cash Items & Reconciliation Adjustments - ...              16798
# 2   Equity Income/(Loss) in Net Earnings - Cash Fl...               -211
# 3   Income Tax Expense - Cash Flow - to Reconcile ...               1330
# 4   Financial Income/(Expense) - Cash Flow - to Re...               1964
# ..                                                ...                ...
# 62  Common Stock Buyback - Net [SCSBN] represents ...               2087
# 63  Depreciation, Depletion & Amortization - Cash ...              13845
# 64  Free Cash Flow to Equity [SFCFE] represents th...               4799
# 65  Free Cash Flow Net of Dividends [SFCFO] repres...               4990
# 66  Free Cash Flow [SFCFL] represents the differen...               7464
#
# [67 rows x 4 columns]

# %% [markdown]
# ### Balance Sheet

# %%
df2 = rd.get_data(['VOD.L'], ['TR.F.BalanceSheet.fieldname', 'TR.F.BalanceSheet.fielddescription', 'TR.F.BalanceSheet'],
                  parameters={'Period': 'FY0', 'reportingState': 'Rsdt', 'curn': 'Native', 'Scale': '6', 'SORTA': 'LISeq'})
df2
# Out:
#     Instrument                              Name  \
# 0        VOD.L                  TR.F.CashSTInvst
# 1        VOD.L                TR.F.CashCashEquiv
# 2        VOD.L                   TR.F.STInvstTot
# 3        VOD.L         TR.F.DerivFinInstrHedgeST
# 4        VOD.L              TR.F.LoansRcvblNetST
# ..         ...                               ...
# 175      VOD.L                 TR.F.UnearnRevTot
# 176      VOD.L                       TR.F.WkgCap
# 177      VOD.L                TR.F.WkgCapNonCash
# 178      VOD.L  TR.F.WkgCapExclOthCurrAssetsLiab
# 179      VOD.L                  TR.F.BVExclOthEq
#
#                                            Description  STD Balance Sheet All
# 0    Cash & Short Term Investments [SCSI] refers to...                15427.0
# 1    Cash & Cash Equivalents [SCAE] represents shor...                 7496.0
# 2    Short-Term Investments - Total [SSTI] represen...                 7931.0
# 3    Derivative Financial Instruments - Hedging - S...                  410.0
# 4    Loans & Receivables - Net - Short-Term [SCLR] ...                10033.0
# ..                                                 ...                    ...
# 175  Unearned Revenue - Total [SUREV] represents th...                 2521.0
# 176  Working Capital [SWCAP] represents a differenc...                -6069.0
# 177  Working Capital - Non-Cash [SNCWC] represents ...               -21496.0
# 178  Working Capital excluding Other Current Assets...                 -885.0
# 179  Book Value excluding Other Equity [STCSEO] rep...                54687.0
#
# [180 rows x 4 columns]

# %% [markdown]
# ### Estimates Data
#
# \- Workspace carries over 260+ types of estimate related to company financials - lets look at some of these briefly
#
# ### Company Estimates
#
# \- Company releases forward looking guidance for quarterly, interim or full year(s) ahead
#
# \- Specify as much detail as you want, includes transcripts of investor meetings, press releases, speaker who said it etc.
#
# \- Both actual value based updates and contextual updates sourced

# %%
df3 = rd.get_data('VOD.L', ['TR.GuidanceDate', 'TR.GuidanceMeasure', 'TR.EstGuidHighValue', 'TR.EstGuidLowValue', 'TR.GuidanceText', 'TR.GuidanceDocType'],
                  {'Period': 'FY1', 'GuidMeasure': 'REV,EBIT,EBITDA', 'GuidDataBasis': 'VAL'})

df3
# Out:
#   Instrument       Activation Date Guidance Measure  Guidance High Value  \
# 0      VOD.L  2022-05-17T10:00:00Z          Revenue          15200000000
# 1      VOD.L  2022-07-25T10:00:00Z          Revenue                 <NA>
# 2      VOD.L  2023-02-01T10:00:00Z           EBITDA                 <NA>
# 3      VOD.L  2022-05-17T10:00:00Z           EBITDA                 <NA>
# 4      VOD.L  2022-11-15T12:00:00Z           EBITDA                 <NA>
#
#    Guidance Low Value                                      Guidance Text  \
# 0         15000000000  And of course, broadening the picture, good gr...
# 1                <NA>  Clearly, within the year, it is front-end load...
# 2                <NA>  And given we're now in February, do you see yo...
# 3                <NA>  As we look into FY '23, there is a degree of m...
# 4                <NA>  EBITDA increased by 1.3% in the quarter, and t...
#
#   The Doc Type
# 0   Transcript
# 1   Transcript
# 2   Transcript
# 3   Transcript
# 4   Transcript

# %% [markdown]
# ### Analyst Estimates
#
# \- Companies depending or their size are followed by sell-side analysts who make forecasts and some sort of recommendation and price target
#
# \- Large companies where there are many analysts following - likely to be more updates - good as more recent events captured
#
# \- List of forecasted items has grown over the decades to include CF and even BS items - but not all analysts may provide detail
#
# \- Expanded coverage of industry specific meterics - see chart below:
#
# ![image.png](attachment:image.png)
#
# \- So lets have a look at how we can get individual analyst estimates for a stock - here we just look at Revenue.

# %%
df4 = rd.get_data(['VOD.L'], ['TR.RevenueEstValue(Period=FY1).date',
                              'TR.RevenueEstValue(Period=FY1).brokername',
                              'TR.RevenueEstValue(Period=FY1).analystname',
                              'TR.RevenueEstValue(Period=FY1).analystcode',
                              'TR.RevenueEstValue(Period=FY1)'])

df4
# Out:
#    Instrument                Date                    Broker Name  \
# 0       VOD.L 2022-06-01 04:55:00  LANDESBANK BADEN-WUERTTEMBERG
# 1       VOD.L 2022-11-15 14:04:00              MORNINGSTAR, INC.
# 2       VOD.L 2023-02-02 04:05:00         CREDIT SUISSE - EUROPE
# 3       VOD.L 2023-02-01 16:18:00                       JPMORGAN
# 4       VOD.L 2023-01-23 05:50:00                  DEUTSCHE BANK
# 5       VOD.L 2022-08-09 06:35:00               SOCIETE GENERALE
# 6       VOD.L 2023-02-14 16:22:00        ESN/BANCA AKROS (ITALY)
# 7       VOD.L 2023-01-09 05:44:00                      BERENBERG
# 8       VOD.L 2023-02-09 04:00:00                            UBS
# 9       VOD.L 2023-02-01 07:53:00                      BERNSTEIN
# 10      VOD.L 2023-02-02 10:30:00       REDBURN (EUROPE) LIMITED
# 11      VOD.L 2023-02-01 16:41:00           NEXTGEN RESEARCH LTD
# 12      VOD.L 2022-11-18 13:29:00         CFRA RESEARCH/NOMURAWM
# 13      VOD.L 2023-01-23 00:20:00                      JEFFERIES
# 14      VOD.L 2023-02-08 21:02:00                       BARCLAYS
# 15      VOD.L 2023-02-01 09:15:00                       ODDO BHF
# 16      VOD.L 2023-02-13 06:23:00               KEPLER CHEUVREUX
# 17      VOD.L 2023-01-25 08:45:00                 ARETE RESEARCH
# 18      VOD.L 2023-02-02 09:00:00              BNP PARIBAS EXANE
# 19      VOD.L 2023-02-01 15:46:00                 BOFA ESTIMATES
# 20      VOD.L 2022-11-17 07:06:00               NUMIS SECURITIES
#
#                  Analyst Name Analyst Code  Revenue - Broker Estimate
# 0           Deuscher, Bettina         4O3B                45950000000
# 1          Correonero, Javier         7WZ3                45554000000
# 2            Bluestone, Jakob         653B                45844973000
# 3              Dattani, Akhil         3MBD                45645000000
# 4             Grindle, Robert         4AIT                45606000000
# 5           Adorisio, Ottavio         4978                45580000000
# 6             De Vita, Andrea         1ABC                47337000000
# 7         Murdock-Smith, Carl         7K6U                45410000000
# 8                  Tang, Polo         4Y98                45722720000
# 9                  Noel, Stan         8CDL                45757000000
# 10               Delfas, Nick         6VB2                47436190000
# 11            Funnell, Justin         87UJ                45729000000
# 12                 Ng, Adrian         8AKS                45900000000
# 13              Dellis, Jerry         4UPP                45591000000
# 14         Patrick, Maurice G         4UH7                45303000000
# 15         Beyazian, Stephane         8FBD                46019000000
# 16  Van Leijenhorst, Matthijs         64TX                45655000000
# 17                Pound, Alex         8ESA                45708000000
# 18             McHugh, Samuel         776T                45660000000
# 19            Wright, David A         6Z0Y                45696150000
# 20              Karidis, John         7FS1                45810500000

# %% [markdown]
# \- Expanded industry metrics - this time for Tech and Telecom - using Verizon. Note these expanded metrics will not be available for all geographies.

# %%
df5 = rd.get_data(['VZ'], ['TR.Subscribers.date', 'TR.Subscribers', 'TR.SubscribersBrokerName',
                           'TR.NetSubscriberAdds.date', 'TR.NetSubscriberAdds', 'TR.NetSubscriberAddsBrokerName',
                           'TR.AvgRevPerUnitEstValue.date', 'TR.AvgRevPerUnitEstValue', 'TR.AvgRevPerUnitEstBrokerName',
                           'TR.ChurnpctEstValue.date', 'TR.ChurnpctEstValue', 'TR.ChurnpctEstBrokerName'],
                  {'Period': 'FY1', 'SDate': '-200', 'EDate': '0', 'Frq': 'D'})
df5.head()
# Out:
#   Instrument                Date  \
# 0         VZ 2021-12-08 06:34:00
# 1         VZ 2022-04-25 00:26:00
# 2         VZ 2022-07-07 02:22:00
# 3         VZ 2021-12-08 06:34:00
# 4         VZ 2022-07-07 02:22:00
#
#    No. Of Subscribers / Users - Broker Estimate           Broker Name  \
# 0                                     142782000  SVB MOFFETTNATHANSON
# 1                                     146510000              JPMORGAN
# 2                                          <NA>              BARCLAYS
# 3                                     142782000  SVB MOFFETTNATHANSON
# 4                                          <NA>              BARCLAYS
#
#                  Date  Net Subscriber Additions - Broker Estimate  \
# 0 2022-01-25 19:25:00                                     1700000
# 1 2022-04-22 17:00:00                                      960000
# 2 2022-03-29 17:39:00                                     3070000
# 3 2021-12-08 06:34:00                                      -93000
# 4 2022-01-26 06:43:00                                     1266000
#
#                    Broker Name                Date  \
# 0      OPPENHEIMER & CO., INC. 2022-04-25 07:05:00
# 1            TRUIST SECURITIES 2021-12-08 06:34:00
# 2  WELLS FARGO SECURITIES, LLC 2022-04-25 07:05:00
# 3         SVB MOFFETTNATHANSON 2021-12-08 06:34:00
# 4          RBC CAPITAL MARKETS 2022-04-25 07:05:00
#
#    Avg Revenue Per Unit / User - Broker Estimate              Broker Name  \
# 0                                          42.84  OPPENHEIMER & CO., INC.
# 1                                          43.46     SVB MOFFETTNATHANSON
# 2                                          42.84  OPPENHEIMER & CO., INC.
# 3                                          43.46     SVB MOFFETTNATHANSON
# 4                                          42.84  OPPENHEIMER & CO., INC.
#
#                  Date  Churn Percentage - Broker Estimate  \
# 0 2022-01-24 06:30:00                                1.58
# 1 2021-12-08 06:34:00                                1.53
# 2 2022-01-25 19:25:00                                1.02
# 3 2022-01-25 17:48:00                                1.07
# 4 2022-01-25 20:27:00                                0.95
#
#                    Broker Name
# 0          RBC CAPITAL MARKETS
# 1         SVB MOFFETTNATHANSON
# 2      OPPENHEIMER & CO., INC.
# 3  WELLS FARGO SECURITIES, LLC
# 4            TRUIST SECURITIES

# %% [markdown]
# ### Consensus Estimates
#
# \- With so many different analyst opinions - consensus estimates developed to capture mean of all analysts
#
# \- Our I/B/E/S (Institutional Brokers Estimates System) is the industry standard, founded in 1976
#
# \- Offers coverage for 22K active companies across 90 countries from over 18K analysts
#
# \- Not all analysts report on all measures - so number of included estimates can vary across measure
#
# \- Some estimates are not included due to staleness
#
# \- Can check variation estimates are by looking at Estimate High, Low and Median
#
# \- Great thing is we can track these consensus estimates on a daily basis
#
# \- Clustering / herd behaviour - can change these metrics rapidly in some cases in other cases its slow
#
# \- To see the impact on shareprice of VOD.L - it is easy just to add a closing shareprice for the last 2000 days.

# %%
df6 = rd.get_data(['VOD.L'], ['TR.RevenueMean(Period=FY1).calcdate',
                              'TR.RevenueMean(Period=FY1)',
                              'TR.RevenueNumIncEstimates(Period=FY1)',
                              'TR.GrossIncomeMean(Period=FY1)',
                              'TR.GrossIncomeNumIncEstimates(Period=FY1)',
                              'TR.PreTaxProfitMean(Period=FY1)',
                              'TR.PreTaxProfitNumIncEstimates(Period=FY1)',
                              'TR.NetProfitMean(Period=FY1)',
                              'TR.NetProfitNumIncEstimates(Period=FY1)',
                              'TR.EPSMean(Period=FY1)',
                              'TR.EPSNumIncEstimates(Period=FY1)',
                              'TR.DPSMean(Period=FY1)',
                              'TR.DPSNumIncEstimates(Period=FY1)',
                              'TR.CLOSEPRICE(Adjusted=1)'],
                  {'SDate': '-2000', 'EDate': '0', 'Frq': 'D'})

df6.index = pd.to_datetime(df6['Calc Date'])
df6
# Out:
#            Instrument   Calc Date  Revenue - Mean  \
# Calc Date
# 2015-04-07      VOD.L  2015-04-07     58286305800
# 2015-04-08      VOD.L  2015-04-08     58286305800
# 2015-04-09      VOD.L  2015-04-09     58286305800
# 2015-04-10      VOD.L  2015-04-10     58250397940
# 2015-04-13      VOD.L  2015-04-13     58250397940
# ...               ...         ...             ...
# 2023-02-28      VOD.L  2023-02-28     45864975420
# 2023-03-01      VOD.L  2023-03-01     45864975420
# 2023-03-02      VOD.L  2023-03-02     45864975420
# 2023-03-03      VOD.L  2023-03-03     45864975420
# 2023-03-06      VOD.L  2023-03-06     45864975420
#
#             Revenue - Number of Included Estimates  Gross Income - Mean  \
# Calc Date
# 2015-04-07                                      25          16621353990
# 2015-04-08                                      25          16621353990
# 2015-04-09                                      25          16621353990
# 2015-04-10                                      25          16621353990
# 2015-04-13                                      25          16621353990
# ...                                            ...                  ...
# 2023-02-28                                      19          21950500000
# 2023-03-01                                      19          21950500000
# 2023-03-02                                      19          21950500000
# 2023-03-03                                      19          21950500000
# 2023-03-06                                      19          21950500000
#
#             Gross Income - Number of Included Estimates  \
# Calc Date
# 2015-04-07                                            3
# 2015-04-08                                            3
# 2015-04-09                                            3
# 2015-04-10                                            3
# 2015-04-13                                            3
# ...                                                 ...
# 2023-02-28                                            2
# 2023-03-01                                            2
# 2023-03-02                                            2
# 2023-03-03                                            2
# 2023-03-06                                            2
#
#             Pre-Tax Profit - Mean  \
# Calc Date
# 2015-04-07             2986573800
# 2015-04-08             2986573800
# 2015-04-09             2986573800
# 2015-04-10             3018836270
# 2015-04-13             3018836270
# ...                           ...
# 2023-02-28             4560513930
# 2023-03-01             4560513930
# 2023-03-02             4560513930
# 2023-03-03             4560513930
# 2023-03-06             4560513930
#
#             Pre-Tax Profit - Number of Included Estimates  Net Income - Mean  \
# Calc Date
# 2015-04-07                                             17         2497532490
# 2015-04-08                                             17         2497532490
# 2015-04-09                                             17         2497532490
# 2015-04-10                                             17         2526198480
# 2015-04-13                                             17         2526198480
# ...                                                   ...                ...
# 2023-02-28                                             15         2923185730
# 2023-03-01                                             15         2923185730
# 2023-03-02                                             15         2923185730
# 2023-03-03                                             15         2923185730
# 2023-03-06                                             15         2923185730
#
#             Net Income - Number of Included Estimates  \
# Calc Date
# 2015-04-07                                         20
# 2015-04-08                                         20
# 2015-04-09                                         20
# 2015-04-10                                         20
# 2015-04-13                                         20
# ...                                               ...
# 2023-02-28                                         15
# 2023-03-01                                         15
# 2023-03-02                                         15
# 2023-03-03                                         15
# 2023-03-06                                         15
#
#             Earnings Per Share - Mean  \
# Calc Date
# 2015-04-07                    0.08251
# 2015-04-08                    0.08251
# 2015-04-09                    0.08251
# 2015-04-10                    0.08242
# 2015-04-13                    0.08242
# ...                               ...
# 2023-02-28                    0.10156
# 2023-03-01                    0.10156
# 2023-03-02                    0.10156
# 2023-03-03                    0.10156
# 2023-03-06                    0.10156
#
#             Earnings Per Share - Number of Included Estimates  \
# Calc Date
# 2015-04-07                                                 24
# 2015-04-08                                                 24
# 2015-04-09                                                 24
# 2015-04-10                                                 24
# 2015-04-13                                                 24
# ...                                                       ...
# 2023-02-28                                                 16
# 2023-03-01                                                 16
# 2023-03-02                                                 16
# 2023-03-03                                                 16
# 2023-03-06                                                 16
#
#             Dividend Per Share - Mean  \
# Calc Date
# 2015-04-07                    0.15326
# 2015-04-08                    0.15326
# 2015-04-09                    0.15326
# 2015-04-10                    0.15326
# 2015-04-13                    0.15326
# ...                               ...
# 2023-02-28                    0.09053
# 2023-03-01                    0.09053
# 2023-03-02                    0.09053
# 2023-03-03                    0.09053
# 2023-03-06                    0.09053
#
#             Dividend Per Share - Number of Included Estimates  Close Price
# Calc Date
# 2015-04-07                                                 22        225.4
# 2015-04-08                                                 22       222.55
# 2015-04-09                                                 22        225.7
# 2015-04-10                                                 22        229.3
# 2015-04-13                                                 22        229.2
# ...                                                       ...          ...
# 2023-02-28                                                 19        99.78
# 2023-03-01                                                 19       100.06
# 2023-03-02                                                 19         99.6
# 2023-03-03                                                 19       100.48
# 2023-03-06                                                 19       101.22
#
# [2001 rows x 15 columns]

# %% [markdown]
# \- Easy to visualise any of these components impacts on shareprice

# %%
df6[['Revenue - Mean', 'Close Price']].plot(subplots=True, figsize=(12, 10))
# Out:
# array([<AxesSubplot: xlabel='Calc Date'>,
#        <AxesSubplot: xlabel='Calc Date'>], dtype=object)

# %%
df6[['Revenue - Mean', 'Close Price']].corr()
# Out:
#                 Revenue - Mean  Close Price
# Revenue - Mean        1.000000     0.756442
# Close Price           0.756442     1.000000

# %% [markdown]
# ### Starmine SmartEstimates
#
# \- Go a step further by trying to weight more successful (in terms of accuracy) analyst opinions more highly
#
# \- More weight is also given to more recent updates whilst those that are stale are completely dropped
#
# \- Lots of papers written about validity and transparency of Starmine SmartEstimates
#
# \- Lets get a selection of these SmartEstimates for 200 days and chart

# %%
df7 = rd.get_data(['VOD.L'], ['TR.RevenueMean(Period=FY1).date',
                              'TR.RevenueSmartEst(Period=FY1)',
                              'TR.RevenueSENumIncEst(Period=FY1)',
                              'TR.GrossIncomeSmartEst(Period=FY1)',
                              'TR.GrossIncomeSENumIncEst(Period=FY1)',
                              'TR.PreTaxProfitSmartEst(Period=FY1)',
                              'TR.PreTaxProfitSENumIncEst(Period=FY1)',
                              'TR.NetprofitSmartEst(Period=FY1)',
                              'TR.NetProfitSENumIncEst(Period=FY1)',
                              'TR.EpsSmartEst(Period=FY1)',
                              'TR.EpsSENumIncEst(Period=FY1)',
                              'TR.DPSSmartEst(Period=FY1)',
                              'TR.DPSSENumIncEst(Period=FY1)',
                              'TR.CLOSEPRICE(Adjusted=1)'],
                  {'SDate': '-200', 'EDate': '0'})

df7.index = pd.to_datetime(df7['Date'])
df7
# Out:
#            Instrument       Date  Revenue - SmartEstimate®  \
# Date
# 2022-05-18      VOD.L 2022-05-18               46059235570
# 2022-05-18      VOD.L 2022-05-18               46059235570
# 2022-05-23      VOD.L 2022-05-23               46036196660
# 2022-05-23      VOD.L 2022-05-23               46036196660
# 2022-05-23      VOD.L 2022-05-23               46036196660
# ...               ...        ...                       ...
# 2023-02-14      VOD.L 2023-02-14               45760662440
# 2023-02-14      VOD.L 2023-02-14               45760662440
# 2023-02-14      VOD.L 2023-02-14               45760662440
# 2023-02-14      VOD.L 2023-02-14               45760662440
# 2023-02-14      VOD.L 2023-02-14               45760662440
#
#             Revenue - SmartEstimate Num of Included Estimates  \
# Date
# 2022-05-18                                                 21
# 2022-05-18                                                 21
# 2022-05-23                                                 21
# 2022-05-23                                                 21
# 2022-05-23                                                 21
# ...                                                       ...
# 2023-02-14                                                 18
# 2023-02-14                                                 18
# 2023-02-14                                                 18
# 2023-02-14                                                 18
# 2023-02-14                                                 18
#
#             Gross Income - SmartEstimate®  Gross Income - SENum Inc Ests  \
# Date
# 2022-05-18                    28634625620                              2
# 2022-05-18                    28634625620                              2
# 2022-05-23                    28634625620                              2
# 2022-05-23                    28634625620                              2
# 2022-05-23                    28634625620                              2
# ...                                   ...                            ...
# 2023-02-14                    20304710440                              2
# 2023-02-14                    20304710440                              2
# 2023-02-14                    20304710440                              2
# 2023-02-14                    20304710440                              2
# 2023-02-14                    20304710440                              2
#
#             Pre-Tax Profit - SmartEstimate®  \
# Date
# 2022-05-18                       4775544280
# 2022-05-18                       4775544280
# 2022-05-23                       4818570130
# 2022-05-23                       4818570130
# 2022-05-23                       4818570130
# ...                                     ...
# 2023-02-14                       4635480820
# 2023-02-14                       4635480820
# 2023-02-14                       4635480820
# 2023-02-14                       4635480820
# 2023-02-14                       4635480820
#
#             Pre-Tax Profit - SmartEstimate Num of Included Estimates  \
# Date
# 2022-05-18                                                 10
# 2022-05-18                                                 10
# 2022-05-23                                                 10
# 2022-05-23                                                 10
# 2022-05-23                                                 10
# ...                                                       ...
# 2023-02-14                                                 14
# 2023-02-14                                                 14
# 2023-02-14                                                 14
# 2023-02-14                                                 14
# 2023-02-14                                                 14
#
#             Net Income - SmartEstimate®  \
# Date
# 2022-05-18                   3307527710
# 2022-05-18                   3307527710
# 2022-05-23                   3368743540
# 2022-05-23                   3368743540
# 2022-05-23                   3368743540
# ...                                 ...
# 2023-02-14                   3112217020
# 2023-02-14                   3112217020
# 2023-02-14                   3112217020
# 2023-02-14                   3112217020
# 2023-02-14                   3112217020
#
#             Net Income - SmarteEstimate Num of Included Estimates  \
# Date
# 2022-05-18                                                  7
# 2022-05-18                                                  7
# 2022-05-23                                                  8
# 2022-05-23                                                  8
# 2022-05-23                                                  8
# ...                                                       ...
# 2023-02-14                                                 14
# 2023-02-14                                                 14
# 2023-02-14                                                 14
# 2023-02-14                                                 14
# 2023-02-14                                                 14
#
#             Earnings Per Share - SmartEstimate®  \
# Date
# 2022-05-18                              0.11527
# 2022-05-18                              0.11527
# 2022-05-23                              0.11587
# 2022-05-23                              0.11587
# 2022-05-23                              0.11587
# ...                                         ...
# 2023-02-14                              0.10975
# 2023-02-14                              0.10975
# 2023-02-14                              0.10975
# 2023-02-14                              0.10975
# 2023-02-14                              0.11088
#
#             Earnings Per Share - SmartEstimate Num of Included Estimates  \
# Date
# 2022-05-18                                                 14
# 2022-05-18                                                 14
# 2022-05-23                                                 14
# 2022-05-23                                                 14
# 2022-05-23                                                 14
# ...                                                       ...
# 2023-02-14                                                 16
# 2023-02-14                                                 16
# 2023-02-14                                                 16
# 2023-02-14                                                 16
# 2023-02-14                                                 16
#
#             Dividend Per Share - SmartEstimate®  \
# Date
# 2022-05-18                              0.09113
# 2022-05-18                              0.09113
# 2022-05-23                              0.09079
# 2022-05-23                              0.09079
# 2022-05-23                              0.09079
# ...                                         ...
# 2023-02-14                                 0.09
# 2023-02-14                                 0.09
# 2023-02-14                                 0.09
# 2023-02-14                                 0.09
# 2023-02-14                                 0.09
#
#             Dividend Per Share - SmartEstimate Num of Included Estimates  \
# Date
# 2022-05-18                                                  9
# 2022-05-18                                                  9
# 2022-05-23                                                  9
# 2022-05-23                                                  9
# 2022-05-23                                                  9
# ...                                                       ...
# 2023-02-14                                                  6
# 2023-02-14                                                  6
# 2023-02-14                                                  6
# 2023-02-14                                                  6
# 2023-02-14                                                  6
#
#             Close Price
# Date
# 2022-05-18       118.46
# 2022-05-18        121.1
# 2022-05-23        126.1
# 2022-05-23       128.84
# 2022-05-23       130.22
# ...                 ...
# 2023-02-14        99.78
# 2023-02-14       100.06
# 2023-02-14         99.6
# 2023-02-14       100.48
# 2023-02-14       101.22
#
# [201 rows x 15 columns]

# %%
df7[['Net Income - SmartEstimate®', 'Close Price']
    ].plot(subplots=True, figsize=(12, 10))
# Out:
# array([<AxesSubplot: xlabel='Date'>, <AxesSubplot: xlabel='Date'>],
#       dtype=object)

# %%
df7[['Net Income - SmartEstimate®', 'Close Price']].corr()
# Out:
#                              Net Income - SmartEstimate®  Close Price
# Net Income - SmartEstimate®                     1.000000     0.846768
# Close Price                                     0.846768     1.000000

# %% [markdown]
# ### Discounted Cash Flow
#
# \- Many ways to approach this sort of valuation task as evidenced by number of textbooks on the subject
#
# \- Instead of us forecasting free cash flow ourselves - we use I/B/E/S consensus - typically these go out 4 years or so
#
# \- After this period, forecasting becomes more challenging - but we need to capture what is known as a terminal value for the remaining cash flows based on some exit multiple
#
# \- We take the most recent EV / FCF multiple and assign that to our last forecasted cash flow number to get our terminal value
#
# \- So lets get some data, first some stock-type data

# %%
df8 = rd.get_data('VOD.L', ['TR.F.DebtTot', 'TR.WACC',
                  'TR.F.ComShrOutsTot(Period=FY0)', 'TR.EVtoFCFSmartEst(Period=FY1)'])
df8
# Out:
#   Instrument  Debt - Total  Weighted Average Cost of Capital, (%)  \
# 0      VOD.L   70092000000                               6.619253
#
#    Common Shares - Outstanding - Total  EV / Free Cash Flow (SmartEstimate ®)
# 0                          28370051346                              22.129953

# %% [markdown]
# \- Next we will get our IBES consensus free cash flow forecasts going out 4 fiscal years. I also include the most recent actual value at the start.

# %%
fcf = rd.get_data('VOD.L', ['TR.FCFMean(Period=FY0)', 'TR.FCFMean(Period=FY1)', 'TR.FCFMean(Period=FY2)',
                            'TR.FCFMean(Period=FY3)', 'TR.FCFMean(Period=FY4)'])
fcf.columns = ['RIC', 'FCF-FY0', 'FCF-FY1', 'FCF-FY2', 'FCF-FY3', 'FCF-FY4']
fcf
# Out:
#      RIC     FCF-FY0     FCF-FY1     FCF-FY2     FCF-FY3     FCF-FY4
# 0  VOD.L  4548615750  4251274200  4190898010  4261346800  4506602110

# %% [markdown]
# \- Next, calculate the net present value (NPV) of these cash flows using WACC as the discount rate.

# %%
dfcf = npf.npv(df8['Weighted Average Cost of Capital, (%)']
               [0], fcf.iloc[0, 2:6].dropna(how=any).tolist())
dfcf
# Out:
# 4884907710.288664

# %% [markdown]
# \- Now calculate our terminal value using the exit multiple we identified - in this case Enterprise Value / Free Cash Flow multiple, and apply this to the last Free Cash Flow forecast (FY4).

# %%
tv_exit = df8['EV / Free Cash Flow (SmartEstimate ®)'][0] * \
    fcf.iloc[0, 2:5].dropna(how=any)[-1]
tv_exit
# Out:
# 94303402320.0957

# %% [markdown]
# \- We now set our flow value to be the sum of our discounted cash flow plus our terminal value.

# %%
flo_val = dfcf + tv_exit
flo_val
# Out:
# 99188310030.38437

# %% [markdown]
# \- Subtract the debt portion from the enterprise value so we are left with our Equity portion - which we can then divide by shares outstanding to get our valuation per share.

# %%
model_price = (flo_val - df8['Debt - Total']) / \
    df8['Common Shares - Outstanding - Total']
model_price
# Out:
# 0    1.025599
# dtype: Float64

# %% [markdown]
# \- As this is a UK share we need to multiply the equity value (which is in pounds) to pence so we can compare it to the quoted shareprice.

# %%
model_price*100
# Out:
# 0    102.559948
# dtype: Float64

# %% [markdown]
# \- Now we can just compare it to the most recent closing price.

# %%
df9 = rd.get_data('VOD.L', 'CF_CLOSE')
df9
# Out:
#   Instrument  CF_CLOSE
# 0      VOD.L    101.22

# %% [markdown]
# ### Peer Group Comparison
#
# \- Refinitiv Data Libraries API provide neat Peers function - retrieve list of Global Peer RICs
#
# \- Easy to scale an intrinsic valuation to a relative valuation or competitor analysis
#
# \- We will use our previous DCF - but you can of course replace or add your own measures such as PER, PCF, PTS, EV/Ebitda, Dividend Yield etc
#
# \- When scaling you may need to handle missing data etc so dealing with exceptions is part of process - however I just drop any problem candidates as we have enough peers
#
# \- Cautionary note: no two companies are identical, differences in balance sheet structures, asset holdings, efficiencies, innovation, performance stability and many other factors all play major roles in divergent outcomes of companies. Also different economic phases can effect companies differently eg NIRP/ZIRP could keep zombie companies alive for longer than normal interest rate environments would tolerate. DCF is just one tool in our armoury.
#
# \- Get all data we need for target and its peers -  I also drop any peers with NAs - Please enter a valid RIC in the cell below

# %%
ric = widgets.Text(
    value='',
    placeholder='Type something',
    description='RIC:',
    disabled=False
)

box_layout = Layout(display='flex',
                    flex_flow='row wrap',
                    align_items='stretch',
                    border='solid',
                    width='100%')

items = [ric]
box = Box(children=items, layout=box_layout)

box
# Out:
# Box(children=(Text(value='', description='RIC:', placeholder='Type something'),), layout=Layout(align_items='s…

# %%
_peers = Peers(ric.value)
peers = rd.get_data([ric.value, *_peers], fields=['TR.CompanyName', 'TR.ExchangeCountry', 'TR.F.DebtTot', 'TR.WACC', 'TR.F.ComShrOutsTot(Period=FY0)',
                                                  'TR.EVtoFCFSmartEst(Period=FY1)', 'TR.FCFMean(Period=FY0)',
                                                  'TR.FCFMean(Period=FY1)', 'TR.FCFMean(Period=FY2)',
                                                  'TR.FCFMean(Period=FY3)', 'TR.FCFMean(Period=FY4)', 'TR.PRICECLOSE'])
peers.columns = ['RIC', 'Name', 'Country', 'Debt - Total', 'WACC %', 'Shs Out',
                 'EV/FCF', 'FCF-FY0', 'FCF-FY1', 'FCF-FY2', 'FCF-FY3', 'FCF-FY4', 'Close Price']
peers['EV/FCF'] = peers['EV/FCF'].astype(float)
peers.dropna(axis=0, how='any', inplace=True)
peers.reset_index(drop=True, inplace=True)
peers
# Out:
#          RIC                                               Name  \
# 0      VOD.L                                 Vodafone Group PLC
# 1       BT.L                                       BT Group PLC
# 2     TEF.MC                                      Telefonica SA
# 3   DTEGn.DE                                Deutsche Telekom AG
# 4     SCMN.S                                        Swisscom AG
# 5   LBTYA.OQ                                 Liberty Global PLC
# 6     KPN.AS                                 Koninklijke KPN NV
# 7    O2Dn.DE                  Telefonica Deutschland Holding AG
# 8    VTWRn.F                                  Vantage Towers AG
# 9    INWT.MI               Infrastrutture Wireless Italiane SpA
# 10   BOUY.PA                                        Bouygues SA
# 11  TELIA.ST                                   Telia Company AB
# 12   PROX.BR                                        Proximus NV
# 13   TNET.BR                           Telenet Group Holding NV
# 14   UTDI.DE                                 United Internet AG
# 15  TEL2b.ST                                           Tele2 AB
# 16  ELISA.HE                                          Elisa Oyj
# 17  SESFd.PA                                             SES SA
# 18    ETL.PA                         Eutelsat Communications SA
# 19    TEL.OL                                        Telenor ASA
# 20    NOS.LS                                        NOS SGPS SA
# 21    GAMA.L                           Gamma Communications PLC
# 22     CRH.I                                            CRH PLC
# 23   SGOB.PA                       Compagnie de Saint Gobain SA
# 24   SGEF.PA                                           Vinci SA
# 25    HOLN.S                                          Holcim AG
# 26   AIRP.PA  L'Air Liquide Societe Anonyme pour l'Etude et ...
# 27   TMUS.OQ                                    T-Mobile US Inc
# 28   AKZO.AS                                      Akzo Nobel NV
# 29    SIKA.S                                            Sika AG
# 30   DSMN.AS                                 Koninklijke DSM NV
# 31  BASFn.DE                                            BASF SE
# 32    GIVN.S                                        Givaudan SA
# 33   TELA.VI                                 Telekom Austria AG
# 34   SY1G.DE                                         Symrise AG
# 35   RWAY.MI                                        Rai Way SpA
# 36  TRUEb.ST                                      Truecaller AB
# 37       T.N                                           AT&T Inc
# 38      VZ.N                         Verizon Communications Inc
#
#                      Country  Debt - Total     WACC %      Shs Out  \
# 0             United Kingdom   70092000000   6.619253  28370051346
# 1             United Kingdom   21945000000   7.027794   9926697743
# 2                      Spain   45388000000   5.000441   5690019933
# 3                    Germany  148164000000   6.098048   4972701341
# 4                Switzerland    7792000000   4.438835     51801943
# 5   United States of America   13763200000   8.230978    459347955
# 6                Netherlands    6290000000   4.654942   4033697579
# 7                    Germany    4898000000   5.649254   2974554993
# 8                    Germany    4203900000   6.811944    505782265
# 9                      Italy    4152716443   5.772689    959906127
# 10                    France   15970000000   5.120251    372661777
# 11                    Sweden   94085000000   4.193124   3932109286
# 12                   Belgium    3536000000   3.812091    322741364
# 13                   Belgium    6654900000   4.815697    107944604
# 14                   Germany    2337942000    6.21408    186715891
# 15                    Sweden   34144000000   4.720255    691011367
# 16                   Finland    1361200000   4.591388    160259695
# 17                    France    4393000000   6.977965    439183567
# 18                    France    3443800000   4.093038    230322045
# 19                    Norway  122984000000    4.26916   1399458033
# 20                  Portugal    1576609000   5.823545    512158953
# 21            United Kingdom      15200000   9.708276     96323054
# 22      Ireland; Republic of   10955000000   7.771335    744742226
# 23                    France   14366000000   8.001052    511362092
# 24                    France   31024000000   5.512601    563596521
# 25               Switzerland   14910000000   8.144544    588564084
# 26                    France   13375700000   6.389503    522226821
# 27  United States of America   83919000000   5.883227   1233960078
# 28               Netherlands    5875000000   7.559684    170437931
# 29               Switzerland    3894800000   8.270628    153670605
# 30               Netherlands    3064000000   8.139022    173075397
# 31                   Germany   20503000000   8.909966    893854929
# 32               Switzerland    5005000000   6.653386      9226814
# 33                   Austria    2550000000   4.939719    664084841
# 34                   Germany    1800727000   6.097889    139772054
# 35                     Italy     105654023   6.513956    268374644
# 36                    Sweden     141515000  10.248764    368839416
# 37  United States of America  136020000000   5.850494   7127591782
# 38  United States of America  150639000000   5.145305   4199861388
#
#         EV/FCF      FCF-FY0      FCF-FY1      FCF-FY2      FCF-FY3  \
# 0    22.129953   4548615750   4251274200   4190898010   4261346800
# 1    28.553058   1178297910   1449455300   1119882890   1122379000
# 2    20.598917   3999372750   3163414850   3117526690   2784790000
# 3    17.394747  11025143750  16510516250  19203349300  20358206670
# 4    24.627437   1543165430   1640206500   1699420500   1744680000
# 5    13.750318   1457274440   1409041170   1168515670   1149965000
# 6    20.079543    876725090    925816170    973358750   1011359700
# 7    23.081770    448662000    549853830    693741430    698247500
# 8    80.999251    371695710    290540630    290022000    338544710
# 9    35.292261    361473310    445992140    512969570    516757600
# 10   28.740443    228078000    831366000   1108563670   1198100500
# 11   20.654503  10419945910   9735058550  11225163360  11030973330
# 12   20.287046    220184500    289853110    350101220    395684630
# 13   21.489579    445371170    352154710    291761500    146486670
# 14   17.459272    461663880    260890000    112498000    327561400
# 15   20.035147   5191324000   5090178780   5873027000   6069810000
# 16   25.730715    359532560    396049890    410061110    394164290
# 17   14.768781    114625000    453843170   1588126000    597276000
# 18   10.823786    479190500    496245830    341974170    440743800
# 19   23.284534  15934938900  14615016460  15355579270  14522202860
# 20  233.606153    -21655500     46018500    134191860    177676830
# 21   16.591694     52427670     61340000     59680000     59125000
# 22   15.628146   2607683180   2677519660   2866125710   3188951080
# 23   12.422820   2426381250   3126122730   3107879460   3408114140
# 24   18.612143   4469971820   4800291820   5398358000   5725417140
# 25   13.653461   2870031600   3124902000   3196936360   3442180800
# 26   36.322264   1978847790   2482758930   2663428210   2850223000
# 27   18.757393   7815424770  13338909090  15780545460  17301125000
# 28   22.809640    132583100    793954850    763760540    783504400
# 29   30.700316    811219920   1119309000   1601922640   1774289330
# 30   31.571755    664752690    753985540    944340800   1037103000
# 31   36.784267   2497737500   2061680000   2087170800   2861126000
# 32   30.852774    722466070    991802530   1043255360   1091848290
# 33   17.413168    518650000    412333330    545700000    477650000
# 34   99.854554    358534920    203438000    511857730    532566790
# 35   42.489792     31687330     34124400     70339600    108393400
# 36   15.097105    629875000    707125000    928050000   1231850000
# 37   16.127916  15881029360  17146616640  17938325900  18099632500
# 38   17.600468  15598170390  17461696770  19782788550  20522714290
#
#         FCF-FY4  Close Price
# 0    4506602110       101.22
# 1    1221065000       148.75
# 2    3344910000        3.965
# 3   20192663330        21.46
# 4    1807332500        585.8
# 5     929986670        20.02
# 6    1081362130        3.231
# 7     675985000        2.958
# 8     432678670        33.74
# 9     572202000        11.39
# 10   1402192000        32.68
# 11  11346750000        27.33
# 12    365833330         8.75
# 13    166870000        14.77
# 14    193620000        20.39
# 15   6047160000        97.46
# 16    432497500        54.26
# 17    628666670         6.45
# 18    270600000        6.585
# 19  15833190000       122.95
# 20    177375000        4.184
# 21     63293500       1210.0
# 22   3402920000        48.46
# 23   3228040330        57.79
# 24   5740500000        109.2
# 25   3163459000         59.3
# 26   3267600000       148.84
# 27  19047000000       143.72
# 28   1073427000         69.5
# 29   1908666670        263.1
# 30   1353337600        118.5
# 31   6169000000       48.255
# 32   1068495670       2828.0
# 33    560100000         7.05
# 34    544283600        95.66
# 35    152550000          5.6
# 36   1476000000        35.31
# 37  18321833330        18.77
# 38  21800000000        38.15

# %% [markdown]
# \- Conduct DCF for all companies and compare closing price with model price

# %%
peers['m_price'] = np.nan
peers['method'] = np.nan
peers['prem/disc'] = np.nan

for i, peer in enumerate(peers['RIC']):
    multiple = peers.iloc[i][7]

    for col in range(12, 9, -1):
        if pd.isnull(peers.iloc[i][col]):
            pass
        else:
            last = col
            break

    dfcf = npf.npv(peers.iloc[i][5], peers.iloc[i, 9:last].tolist())
    if not pd.isna(dfcf):
        if dfcf > 0:
            if pd.isnull(multiple) or multiple == "NaN":
                tv_exit = (peers.iloc[i][last] * (1 + 0.1)
                           ) / ((peers.iloc[i]['WACC %']) - 1)
                peers['method'][i] = 'perpetual growth'
            elif peers.iloc[i][last] < 0:
                tv_exit = multiple * peers.iloc[i, 9:last].mean()
                peers['method'][i] = 'multiple - fcfAvg'
            else:
                tv_exit = multiple * peers.iloc[i][last]
                peers['method'][i] = 'multiple'

            flo_val = dfcf + tv_exit
            model_price = (
                flo_val - peers.iloc[i]['Debt - Total']) / peers.iloc[i]['Shs Out']
            peers['m_price'][i] = model_price

            if peers.iloc[i][2] == 'United Kingdom' or peers.iloc[i][2] == 'South Africa':
                peers['m_price'][i] = peers['m_price'][i]*100

            if peers['m_price'][i] <= 0:
                peers['m_price'][i] = np.nan

            if not pd.isnull(peers.iloc[i]['Close Price']):
                if not pd.isnull(peers.iloc[i]['m_price']):
                    peers['prem/disc'][i] = (peers.iloc[i]['Close Price'] /
                                             peers.iloc[i]['m_price']-1) * 100
    else:
        peers.iloc[i]['m_price'] = np.nan

# %%
peers.dropna(axis=0, how='any', inplace=True)
peers.reset_index(drop=True, inplace=True)
peers
# Out:
#          RIC                                               Name  \
# 0      VOD.L                                 Vodafone Group PLC
# 1       BT.L                                       BT Group PLC
# 2   DTEGn.DE                                Deutsche Telekom AG
# 3     SCMN.S                                        Swisscom AG
# 4   LBTYA.OQ                                 Liberty Global PLC
# 5    VTWRn.F                                  Vantage Towers AG
# 6    INWT.MI               Infrastrutture Wireless Italiane SpA
# 7   TELIA.ST                                   Telia Company AB
# 8    TNET.BR                           Telenet Group Holding NV
# 9    UTDI.DE                                 United Internet AG
# 10  TEL2b.ST                                           Tele2 AB
# 11  ELISA.HE                                          Elisa Oyj
# 12    ETL.PA                         Eutelsat Communications SA
# 13    TEL.OL                                        Telenor ASA
# 14    GAMA.L                           Gamma Communications PLC
# 15     CRH.I                                            CRH PLC
# 16   SGOB.PA                       Compagnie de Saint Gobain SA
# 17   SGEF.PA                                           Vinci SA
# 18    HOLN.S                                          Holcim AG
# 19   AIRP.PA  L'Air Liquide Societe Anonyme pour l'Etude et ...
# 20   TMUS.OQ                                    T-Mobile US Inc
# 21   AKZO.AS                                      Akzo Nobel NV
# 22    SIKA.S                                            Sika AG
# 23   DSMN.AS                                 Koninklijke DSM NV
# 24  BASFn.DE                                            BASF SE
# 25    GIVN.S                                        Givaudan SA
# 26   TELA.VI                                 Telekom Austria AG
# 27   SY1G.DE                                         Symrise AG
# 28   RWAY.MI                                        Rai Way SpA
# 29  TRUEb.ST                                      Truecaller AB
# 30       T.N                                           AT&T Inc
# 31      VZ.N                         Verizon Communications Inc
#
#                      Country  Debt - Total     WACC %      Shs Out     EV/FCF  \
# 0             United Kingdom   70092000000   6.619253  28370051346  22.129953
# 1             United Kingdom   21945000000   7.027794   9926697743  28.553058
# 2                    Germany  148164000000   6.098048   4972701341  17.394747
# 3                Switzerland    7792000000   4.438835     51801943  24.627437
# 4   United States of America   13763200000   8.230978    459347955  13.750318
# 5                    Germany    4203900000   6.811944    505782265  80.999251
# 6                      Italy    4152716443   5.772689    959906127  35.292261
# 7                     Sweden   94085000000   4.193124   3932109286  20.654503
# 8                    Belgium    6654900000   4.815697    107944604  21.489579
# 9                    Germany    2337942000    6.21408    186715891  17.459272
# 10                    Sweden   34144000000   4.720255    691011367  20.035147
# 11                   Finland    1361200000   4.591388    160259695  25.730715
# 12                    France    3443800000   4.093038    230322045  10.823786
# 13                    Norway  122984000000    4.26916   1399458033  23.284534
# 14            United Kingdom      15200000   9.708276     96323054  16.591694
# 15      Ireland; Republic of   10955000000   7.771335    744742226  15.628146
# 16                    France   14366000000   8.001052    511362092  12.422820
# 17                    France   31024000000   5.512601    563596521  18.612143
# 18               Switzerland   14910000000   8.144544    588564084  13.653461
# 19                    France   13375700000   6.389503    522226821  36.322264
# 20  United States of America   83919000000   5.883227   1233960078  18.757393
# 21               Netherlands    5875000000   7.559684    170437931  22.809640
# 22               Switzerland    3894800000   8.270628    153670605  30.700316
# 23               Netherlands    3064000000   8.139022    173075397  31.571755
# 24                   Germany   20503000000   8.909966    893854929  36.784267
# 25               Switzerland    5005000000   6.653386      9226814  30.852774
# 26                   Austria    2550000000   4.939719    664084841  17.413168
# 27                   Germany    1800727000   6.097889    139772054  99.854554
# 28                     Italy     105654023   6.513956    268374644  42.489792
# 29                    Sweden     141515000  10.248764    368839416  15.097105
# 30  United States of America  136020000000   5.850494   7127591782  16.127916
# 31  United States of America  150639000000   5.145305   4199861388  17.600468
#
#         FCF-FY0      FCF-FY1      FCF-FY2      FCF-FY3      FCF-FY4  \
# 0    4548615750   4251274200   4190898010   4261346800   4506602110
# 1    1178297910   1449455300   1119882890   1122379000   1221065000
# 2   11025143750  16510516250  19203349300  20358206670  20192663330
# 3    1543165430   1640206500   1699420500   1744680000   1807332500
# 4    1457274440   1409041170   1168515670   1149965000    929986670
# 5     371695710    290540630    290022000    338544710    432678670
# 6     361473310    445992140    512969570    516757600    572202000
# 7   10419945910   9735058550  11225163360  11030973330  11346750000
# 8     445371170    352154710    291761500    146486670    166870000
# 9     461663880    260890000    112498000    327561400    193620000
# 10   5191324000   5090178780   5873027000   6069810000   6047160000
# 11    359532560    396049890    410061110    394164290    432497500
# 12    479190500    496245830    341974170    440743800    270600000
# 13  15934938900  14615016460  15355579270  14522202860  15833190000
# 14     52427670     61340000     59680000     59125000     63293500
# 15   2607683180   2677519660   2866125710   3188951080   3402920000
# 16   2426381250   3126122730   3107879460   3408114140   3228040330
# 17   4469971820   4800291820   5398358000   5725417140   5740500000
# 18   2870031600   3124902000   3196936360   3442180800   3163459000
# 19   1978847790   2482758930   2663428210   2850223000   3267600000
# 20   7815424770  13338909090  15780545460  17301125000  19047000000
# 21    132583100    793954850    763760540    783504400   1073427000
# 22    811219920   1119309000   1601922640   1774289330   1908666670
# 23    664752690    753985540    944340800   1037103000   1353337600
# 24   2497737500   2061680000   2087170800   2861126000   6169000000
# 25    722466070    991802530   1043255360   1091848290   1068495670
# 26    518650000    412333330    545700000    477650000    560100000
# 27    358534920    203438000    511857730    532566790    544283600
# 28     31687330     34124400     70339600    108393400    152550000
# 29    629875000    707125000    928050000   1231850000   1476000000
# 30  15881029360  17146616640  17938325900  18099632500  18321833330
# 31  15598170390  17461696770  19782788550  20522714290  21800000000
#
#     Close Price        m_price    method    prem/disc
# 0        101.22    1390.585373  multiple   -92.721051
# 1        148.75    1555.871862  multiple   -90.439444
# 2         21.46      21.645968  multiple    -0.859135
# 3         585.8   17333.205618  multiple   -96.620360
# 4         20.02      36.094533  multiple   -44.534537
# 5         33.74      17.057014  multiple    97.807188
# 6         11.39       0.497376  multiple  2190.018693
# 7         27.33      51.350883  multiple   -46.777936
# 8         14.77       1.991704  multiple   641.576117
# 9         20.39      38.496362  multiple   -47.033956
# 10        97.46     691.270053  multiple   -85.901313
# 11        54.26     115.793917  multiple   -53.140889
# 12        6.585       0.232907  multiple  2727.308866
# 13       122.95    1323.063839  multiple   -90.707176
# 14       1210.0   65905.261580  multiple   -98.164031
# 15        48.46     158.819318  multiple   -69.487339
# 16        57.79     252.194001  multiple   -77.085101
# 17        109.2     820.614151  multiple   -86.692893
# 18         59.3     269.265174  multiple   -77.977100
# 19       148.84     543.479235  multiple   -72.613489
# 20       143.72     855.047430  multiple   -83.191576
# 21         69.5      24.074958  multiple   188.681711
# 22        263.1    1373.971838  multiple   -80.851136
# 23        118.5     442.890994  multiple   -73.243981
# 24       48.255     114.238329  multiple   -57.759361
# 25       2828.0  221005.029628  multiple   -98.720391
# 26         7.05       2.487909  multiple   183.370519
# 27        95.66     236.160092  multiple   -59.493580
# 28          5.6       0.529613  multiple   957.376415
# 29        35.31      62.432105  multiple   -43.442561
# 30        18.77      25.254708  multiple   -25.677223
# 31        38.15     110.530788  multiple   -65.484730

# %% [markdown]
# ### Relative Valuation
#
# \- Now we can place VOD.L in a DCF relative valuation space amongst its peers
#
# \- Can easily adapt to all manner of factors and metrics
#
# \- Outlier handling important - xlim or ylim parameters useful or explicit exclusion may also be required - examples of both. If the chart has outliers try uncommenting the xlim and ylim parameters below and re-running the cell
#
# \- Linear regression up first

# %%
ax1 = peers.plot.scatter(x='prem/disc', y='EV/FCF', figsize=(15, 10))

for i, ric in enumerate(peers['RIC']):
    if not pd.isnull(peers['prem/disc'][i]):
        if not pd.isnull(peers['EV/FCF'][i]):
            # ax1.set_ylim(0,100) if you have outliers user these parameters
            # ax1.set_xlim(-100, 100) if you have outliers user these parameter
            ax1.text(x=peers['prem/disc'][i]+0.3,
                     y=peers['EV/FCF'][i]+0.3, s=peers['RIC'][i])

X, Y = peers['prem/disc'].values.reshape(-1,
                                         1), peers['EV/FCF'].values.reshape(-1, 1)
ax1.plot(X, LinearRegression().fit(X, Y).predict(X))

# %% [markdown]
# ### Clustering
#
# \- Try to extend our relative valuation study to group similar companies into clusters. We saw previously there seemed to be a steep negative relationship between our two variables
#
# \- However are there perhaps more useful ways of classifying this distribution eg Do companies that have very high EV/FCF multiples really belong in the same group as those that have low or more reasonable EV/FCF?
#
# \- Thankfully yes - here we use an unsupervised algorithm - the algo generates the group labels from the observed data
#
# \- Many ways of doing this - we look at 2 - KMeans clustering and Gaussian Mixture Models, popular in the literature.
#
# \- I am interested in classifying the bulk of observations so I more formally remove outliers

# %%
# You may need to change these to what seems sensible for each universe
exoutlier = peers[(peers['prem/disc'] < 75) & (peers['EV/FCF'] < 60)]
X = exoutlier[['prem/disc', 'EV/FCF']].values

# %% [markdown]
# ### KMeans Clustering
#
# \- Determine optimal amount of clusters using elbow chart. Conduct KMeans 10 times and graph the intertia_ property ==> tells us 2-3 clusters is optimal
#
# \- Use n_clusters = 3 to generate classification and plot it

# %%
inertia = []
K = range(1, 10)
for k in K:
    km = KMeans(n_clusters=k)
    km.fit(X)
    inertia.append(km.inertia_)

plt.pyplot.plot(K, inertia, 'bx-')

# %%
km = KMeans(n_clusters=3)
km.fit(X)
pred = km.predict(X)
clusters = unique(pred)
for cluster in clusters:
    row = where(pred == cluster)
    plt.pyplot.scatter(X[row, 0], X[row, 1])
plt.pyplot.show()

# %% [markdown]
# ### Gaussian Mixture Models
#
# \- Same way use n_components=3 and generate cluster groupings

# %%
model = GaussianMixture(n_components=3)
model.fit(X)
pred = model.predict(X)
clusters = unique(pred)
for cluster in clusters:
    row = where(pred == cluster)
    plt.pyplot.scatter(X[row, 0], X[row, 1])
plt.pyplot.show()

# %% [markdown]
# \- In this case simple linear regression works rather well
#
# \- Some merit in groupings suggested by KM and GMM
#
# \- Which to use could depend on use case but can provide further information for your quantamental analysis

# %%
rd.close_session()

# %% [markdown]
# **Further Resources for Refinitiv Data Libraries API on Developer Community Portal**
#
# * [Overview](https://developers.refinitiv.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python)
# * [Quick Start ](https://developers.refinitiv.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/quick-start)
# * [Documentation](https://developers.refinitiv.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/documentation)
# * [Tutorials](https://developers.refinitiv.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/tutorials)
# * [Q&A Forums](https://community.developers.refinitiv.com/spaces/321/index.html)
